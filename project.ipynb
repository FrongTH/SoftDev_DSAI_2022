# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns

# %%
# !dir "./data"
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 6825-FA1F
#
#  Directory of C:\Users\User\Documents\Pj\data
#
# 08/19/2022  07:40 PM    <DIR>          .
# 08/19/2022  07:40 PM    <DIR>          ..
# 08/18/2022  11:28 PM           103,000 german_data-numeric.txt
# 08/18/2022  11:28 PM            80,793 german_data.txt
#                2 File(s)        183,793 bytes
#                2 Dir(s)  43,014,451,200 bytes free

# %%
# """Description
# Attribute 1: (qualitative)
# Status of existing checking account
# A11 : ... < 0 DM
# A12 : 0 <= ... < 200 DM
# A13 : ... >= 200 DM / salary assignments for at least 1 year
# A14 : no checking account
# _____________________________________________________________________________________________
# Attribute 2: (numerical)
# Duration in month
# _____________________________________________________________________________________________
# Attribute 3: (qualitative)
# Credit history
# A30 : no credits taken/ all credits paid back duly
# A31 : all credits at this bank paid back duly
# A32 : existing credits paid back duly till now
# A33 : delay in paying off in the past
# A34 : critical account/ other credits existing (not at this bank)
# _____________________________________________________________________________________________
# Attribute 4: (qualitative)
# Purpose
# A40 : car (new)
# A41 : car (used)
# A42 : furniture/equipment
# A43 : radio/television
# A44 : domestic appliances
# A45 : repairs
# A46 : education
# A47 : (vacation - does not exist?)
# A48 : retraining
# A49 : business
# A410 : others
# _____________________________________________________________________________________________
# Attribute 5: (numerical)
# Credit amount
# _____________________________________________________________________________________________
# Attibute 6: (qualitative)
# Savings account/bonds
# A61 : ... < 100 DM
# A62 : 100 <= ... < 500 DM
# A63 : 500 <= ... < 1000 DM
# A64 : .. >= 1000 DM
# A65 : unknown/ no savings account
# _____________________________________________________________________________________________
# Attribute 7: (qualitative)
# Present employment since
# A71 : unemployed
# A72 : ... < 1 year
# A73 : 1 <= ... < 4 years
# A74 : 4 <= ... < 7 years
# A75 : .. >= 7 years
# _____________________________________________________________________________________________
# Attribute 8: (numerical)
# Installment rate in percentage of disposable income
# _____________________________________________________________________________________________
# Attribute 9: (qualitative)
# Personal status and sex
# A91 : male : divorced/separated
# A92 : female : divorced/separated/married
# A93 : male : single
# A94 : male : married/widowed
# A95 : female : single
# _____________________________________________________________________________________________
# Attribute 10: (qualitative)
# Other debtors / guarantors
# A101 : none
# A102 : co-applicant
# A103 : guarantor
# _____________________________________________________________________________________________
# Attribute 11: (numerical)
# Present residence since
# _____________________________________________________________________________________________
# Attribute 12: (qualitative)
# Property
# A121 : real estate
# A122 : if not A121 : building society savings agreement/ life insurance
# A123 : if not A121/A122 : car or other, not in attribute 6
# A124 : unknown / no property
# _____________________________________________________________________________________________
# Attribute 13: (numerical)
# Age in years
# _____________________________________________________________________________________________
# Attribute 14: (qualitative)
# Other installment plans
# A141 : bank
# A142 : stores
# A143 : none
# _____________________________________________________________________________________________
# Attribute 15: (qualitative)
# Housing
# A151 : rent
# A152 : own
# A153 : for free
# _____________________________________________________________________________________________
# Attribute 16: (numerical)
# Number of existing credits at this bank
# _____________________________________________________________________________________________
# Attribute 17: (qualitative)
# Job
# A171 : unemployed/ unskilled - non-resident
# A172 : unskilled - resident
# A173 : skilled employee / official
# A174 : management/ self-employed/
# highly qualified employee/ officer
# _____________________________________________________________________________________________
# Attribute 18: (numerical)
# Number of people being liable to provide maintenance for
# _____________________________________________________________________________________________
# Attribute 19: (qualitative)
# Telephone
# A191 : none
# A192 : yes, registered under the customers name
# _____________________________________________________________________________________________
# Attribute 20: (qualitative)
# foreign worker
# A201 : yes
# A202 : no
# _____________________________________________________________________________________________
# """

# %%
#data link https://archive.ics.uci.edu/ml/datasets/Statlog+%28German+Credit+Data%29
header_column = ["Status of existing checking account",
                "Duration in month",
                "Credit history",
                "Purpose",
                "Credit amount",
                "Savings account/bonds",
                "Present employment since",
                "Installment rate in percentage of disposable income",
                "Personal status and sex",
                "Other debtors / guarantors",
                "Present residence since",
                "Property",
                "Age in years",
                "Other installment plans",
                "Housing",
                "Number of existing credits at this bank",
                "Job",
                "Number of people being liable to provide maintenance for",
                "Telephone",
                "foreign worker",
                "actual classification"]

data = pd.read_csv("./data/german_data.txt", sep = " ", names = header_column)
df = pd.DataFrame(data = data, index = [i for i in range(0,1000)])
df
# print(data)
# Out:
#     Status of existing checking account  Duration in month Credit history  \
# 0                                   A11                  6            A34
# 1                                   A12                 48            A32
# 2                                   A14                 12            A34
# 3                                   A11                 42            A32
# 4                                   A11                 24            A33
# ..                                  ...                ...            ...
# 995                                 A14                 12            A32
# 996                                 A11                 30            A32
# 997                                 A14                 12            A32
# 998                                 A11                 45            A32
# 999                                 A12                 45            A34
#
#     Purpose  Credit amount Savings account/bonds Present employment since  \
# ...

# %% [markdown]
# # Data Preprocessing

# %%
df.dtypes
# Out:
# Status of existing checking account                         object
# Duration in month                                            int64
# Credit history                                              object
# Purpose                                                     object
# Credit amount                                                int64
# Savings account/bonds                                       object
# Present employment since                                    object
# Installment rate in percentage of disposable income          int64
# Personal status and sex                                     object
# Other debtors / guarantors                                  object
# Present residence since                                      int64
# Property                                                    object
# Age in years                                                 int64
# Other installment plans                                     object
# ...

# %%
df.isnull()
# Out:
#      Status of existing checking account  Duration in month  Credit history  \
# 0                                  False              False           False
# 1                                  False              False           False
# 2                                  False              False           False
# 3                                  False              False           False
# 4                                  False              False           False
# ..                                   ...                ...             ...
# 995                                False              False           False
# 996                                False              False           False
# 997                                False              False           False
# 998                                False              False           False
# 999                                False              False           False
#
# ...

# %%
df.isnull().sum()
# Out:
# Status of existing checking account                         0
# Duration in month                                           0
# Credit history                                              0
# Purpose                                                     0
# Credit amount                                               0
# Savings account/bonds                                       0
# Present employment since                                    0
# Installment rate in percentage of disposable income         0
# Personal status and sex                                     0
# Other debtors / guarantors                                  0
# Present residence since                                     0
# Property                                                    0
# Age in years                                                0
# Other installment plans                                     0
# Housing                                                     0
# ...

# %% [markdown]
# ## Numerical data distribution

# %%
df.describe( )
# Out:
#        Duration in month  Credit amount  \
# count        1000.000000    1000.000000
# mean           20.903000    3271.258000
# std            12.058814    2822.736876
# min             4.000000     250.000000
# 25%            12.000000    1365.500000
# 50%            18.000000    2319.500000
# 75%            24.000000    3972.250000
# max            72.000000   18424.000000
#
#        Installment rate in percentage of disposable income  \
# count                                        1000.000000
# mean                                            2.973000
# std                                             1.118715
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             4.000000
#
#        Present residence since  Age in years  \
# ...

# %%
df.hist(figsize=(14,14), xrot=45)
plt.show()

# %%
From the histogram, I noted there are no potntial outliers in our dataset. However, our actual target varibale

# %% [markdown]
# ## Categorical data distribution

# %%
obj_df = df.select_dtypes(include=['object']).copy()
obj_df.head()
# Out:
#   Status of existing checking account Credit history Purpose  \
# 0                                 A11            A34     A43
# 1                                 A12            A32     A43
# 2                                 A14            A34     A46
# 3                                 A11            A32     A42
# 4                                 A11            A33     A40
#
#   Savings account/bonds Present employment since Personal status and sex  \
# 0                   A65                      A75                     A93
# 1                   A61                      A73                     A92
# 2                   A61                      A74                     A93
# 3                   A61                      A74                     A93
# 4                   A61                      A73                     A93
#
#   Other debtors / guarantors Property Other installment plans Housing   Job  \
# 0                       A101     A121                    A143    A152  A173
# ...

# %%
obj_df.nunique()
# Out:
# Status of existing checking account     4
# Credit history                          5
# Purpose                                10
# Savings account/bonds                   5
# Present employment since                5
# Personal status and sex                 4
# Other debtors / guarantors              3
# Property                                4
# Other installment plans                 3
# Housing                                 3
# Job                                     4
# Telephone                               2
# foreign worker                          2
# dtype: int64

# %%
for column in obj_df:
    if df[column].nunique() == 5:
        sns.countplot(y=column, data=data)
        plt.show()

# %%
for column in df.select_dtypes(include='object'):
    if df[column].nunique() == 4:
        sns.countplot(y=column, data=data)
        plt.show()

# %%
for column in df.select_dtypes(include='object'):
    if df[column].nunique() == 3:
        sns.countplot(y=column, data=data)
        plt.show()

# %%
for column in df.select_dtypes(include='object'):
    if df[column].nunique() == 2:
        sns.countplot(y=column, data=data)
        plt.show()

# %%
for column in df.select_dtypes(include='object'):
    if df[column].nunique() == 10:
        sns.countplot(y=column, data=data)
        plt.show()

# %% [markdown]
# I created a For loop. For each categorical feature, a countplot will be displayed to show how the classes are distributed for that feature. The line df.select_dtypes(include=’object’) selects the categorical columns with their values and displays them. I will also include an If-statement so as to pick only the columns with classes using the line Series.nunique().

# %%
Categorical feature
Ordinal features
Continuous features

# %%
corrs = df.corr()
corrs
# Out:
#                                                     Duration in month  \
# Duration in month                                            1.000000
# Credit amount                                                0.624984
# Installment rate in percentage of disposable in...           0.074749
# Present residence since                                      0.034067
# Age in years                                                -0.036136
# Number of existing credits at this bank                     -0.011284
# Number of people being liable to provide mainte...          -0.023834
# actual classification                                        0.214927
#
#                                                     Credit amount  \
# Duration in month                                        0.624984
# Credit amount                                            1.000000
# Installment rate in percentage of disposable in...      -0.271316
# Present residence since                                  0.028926
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corrs, cmap='RdBu_r', annot=True)
plt.show()

# %% [markdown]
# ## Target class distribution

# %%
df["actual classification"].value_counts()
# Out:
# 1    700
# 2    300
# Name: actual classification, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(10,5))
data['actual classification'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('actual classification')
ax[0].set_ylabel('')
sns.countplot('actual classification',data=data,ax=ax[1])
ax[1].set_title('actual classification')
plt.show()
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# We can see that there is huge class imbalance which is a very important observation. This has great influence on how to select instances for training and testing. It is recommended to stratify the data when randomly selecting in order to keep the same distribution of classes in training and testing sets. In some cases techniques like oversampling or undersampling may need to be used to restore class balance for better model training. Moreover, this will even have an effect on choosing the classification model and whether it can deal with class imbalance appropriately or no

# %% [markdown]
# ## Feature Engineering

# %%
# class count
class_count_1, class_count_2 = df['actual classification'].value_counts()

# Separate class
class_1 = df[df['actual classification'] == 1]
class_2 = df[df['actual classification'] == 2]# print the shape of the class
print('class 1:', class_1.shape)
print('class 2:', class_2.shape)
# Out:
# class 1: (700, 21)
# class 2: (300, 21)

# %%
# Random Over-Sampling(adding more copies to the minority class)
class_2_over = class_2.sample(class_count_1, replace=True)

test_over = pd.concat([class_2_over, class_1], axis=0)

print("total class of 1 and 2:\n",test_over['actual classification'].value_counts())# plot the count after under-sampeling
test_over['actual classification'].value_counts().plot(kind='bar', title='count (target)')
# Out:
# total class of 1 and 2:
#  1    700
# 2    700
# Name: actual classification, dtype: int64
# <AxesSubplot:title={'center':'count (target)'}>

# %% [markdown]
# ## Label Encoding

# %%
df["Status of existing checking account"] = df["Status of existing checking account"].astype('category')
df["Credit history"] = df["Credit history"].astype('category')
df["Purpose"] = df["Purpose"].astype('category')
df["Savings account/bonds"] = df["Savings account/bonds"].astype('category')
df["Present employment since"] = df["Present employment since"].astype('category')
df["Personal status and sex"] = df["Personal status and sex"].astype('category')
df["Other debtors / guarantors"] = df["Other debtors / guarantors"].astype('category')
df["Property"] = df["Property"].astype('category')
df["Other installment plans"] = df["Other installment plans"].astype('category')
df["Housing"] = df["Housing"].astype('category')
df["Job"] = df["Job"].astype('category')
df["Telephone"] = df["Telephone"].astype('category')
df["foreign worker"] =df["foreign worker"].astype('category')

df.dtypes
# Out:
# Status of existing checking account                         category
# Duration in month                                              int64
# Credit history                                              category
# Purpose                                                     category
# Credit amount                                                  int64
# Savings account/bonds                                       category
# Present employment since                                    category
# Installment rate in percentage of disposable income            int64
# Personal status and sex                                     category
# Other debtors / guarantors                                  category
# Present residence since                                        int64
# Property                                                    category
# Age in years                                                   int64
# Other installment plans                                     category
# ...

# %%
df["Status of existing checking account_cat"] = df["Status of existing checking account"].cat.codes
df["Credit history_cat"] = df["Credit history"].astype('category').cat.codes
df["Purpose_cat"] = df["Purpose"].astype('category').cat.codes
df["Savings account/bonds_cat"] = df["Savings account/bonds"].astype('category').cat.codes
df["Present employment since_cat"] = df["Present employment since"].astype('category').cat.codes
df["Personal status and sex_cat"] = df["Personal status and sex"].astype('category').cat.codes
df["Other debtors / guarantors_cat"] = df["Other debtors / guarantors"].astype('category').cat.codes
df["Property_cat"] = obj_df["Property"].astype('category').cat.codes
df["Other installment plans_cat"] = df["Other installment plans"].astype('category').cat.codes
df["Housing_cat"] = df["Housing"].astype('category').cat.codes
df["Job_cat"] = df["Job"].astype('category').cat.codes
df["Telephone_cat"] = df["Telephone"].astype('category').cat.codes
df["foreign worker_cat"] =df["foreign worker"].astype('category').cat.codes
df = df.drop(columns=["Status of existing checking account", "Credit history", "Purpose","Savings account/bonds","Present employment since","Personal status and sex","Other debtors / guarantors","Property","Other installment plans","Housing","Job","Telephone","foreign worker"])
df.head()
# Out:
#    Duration in month  Credit amount  \
# 0                  6           1169
# 1                 48           5951
# 2                 12           2096
# 3                 42           7882
# 4                 24           4870
#
#    Installment rate in percentage of disposable income  \
# 0                                                  4
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  3
#
#    Present residence since  Age in years  \
# 0                        4            67
# 1                        2            22
# 2                        3            49
# 3                        4            45
# 4                        4            53
#
#    Number of existing credits at this bank  \
# 0                                        2
# 1                                        1
# ...

# %%
df.dtypes
# Out:
# Duration in month                                           int64
# Credit amount                                               int64
# Installment rate in percentage of disposable income         int64
# Present residence since                                     int64
# Age in years                                                int64
# Number of existing credits at this bank                     int64
# Number of people being liable to provide maintenance for    int64
# actual classification                                       int64
# Status of existing checking account_cat                      int8
# Credit history_cat                                           int8
# Purpose_cat                                                  int8
# Savings account/bonds_cat                                    int8
# Present employment since_cat                                 int8
# Personal status and sex_cat                                  int8
# ...

# %% [markdown]
# ## Feature Selection

# %%
### Train test split to avoid overfitting
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop(labels=['actual classification'], axis=1),df['actual classification'],test_size=0.3,random_state=0)

# %%
X_train.head()
# Out:
#      Duration in month  Credit amount  \
# 105                 24          11938
# 68                  36           1819
# 479                 15           1478
# 399                 24           1516
# 434                  9           2136
#
#      Installment rate in percentage of disposable income  \
# 105                                                  2
# 68                                                   4
# 479                                                  4
# 399                                                  4
# 434                                                  3
#
#      Present residence since  Age in years  \
# 105                        3            39
# 68                         4            37
# 479                        4            44
# 399                        1            43
# 434                        2            25
#
#      Number of existing credits at this bank  \
# 105                                        2
# ...

# %%
from sklearn.feature_selection import mutual_info_classif
# determine the mutual information
mutual_info = mutual_info_classif(X_train, y_train)
mutual_info
# Out:
# array([0.06331896, 0.02965158, 0.        , 0.02433244, 0.02801307,
#        0.00459398, 0.02156534, 0.0786593 , 0.03019558, 0.00784406,
#        0.        , 0.        , 0.        , 0.03290167, 0.00150531,
#        0.02993819, 0.        , 0.02370648, 0.00248976, 0.        ])

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns
mutual_info.sort_values(ascending=False)
# Out:
# Status of existing checking account_cat                     0.078659
# Duration in month                                           0.063319
# Other debtors / guarantors_cat                              0.032902
# Credit history_cat                                          0.030196
# Other installment plans_cat                                 0.029938
# Credit amount                                               0.029652
# Age in years                                                0.028013
# Present residence since                                     0.024332
# Job_cat                                                     0.023706
# Number of people being liable to provide maintenance for    0.021565
# Purpose_cat                                                 0.007844
# Number of existing credits at this bank                     0.004594
# Telephone_cat                                               0.002490
# Property_cat                                                0.001505
# ...

# %%
#let's plot the ordered mutual_info values per feature
mutual_info.sort_values(ascending=False).plot.bar(figsize=(20, 8))
# Out:
# <AxesSubplot:>

# %%
from sklearn.feature_selection import SelectKBest

# %%
#Now we Will select the  top 5 important features
sel_five_cols = SelectKBest(mutual_info_classif, k=10)
sel_five_cols.fit(X_train, y_train)
X_train.columns[sel_five_cols.get_support()]
# Out:
# Index(['Duration in month', 'Credit amount',
#        'Installment rate in percentage of disposable income',
#        'Status of existing checking account_cat', 'Purpose_cat',
#        'Savings account/bonds_cat', 'Present employment since_cat',
#        'Property_cat', 'Other installment plans_cat', 'Telephone_cat'],
#       dtype='object')

# %%
# Feature Scaling  
from sklearn.preprocessing import StandardScaler  
sc = StandardScaler()  
x_train = sc.fit_transform(X_train)  
x_test = sc.transform(X_test)

# %%
# Fitting Naive Bayes to the Training set  
from sklearn.naive_bayes import GaussianNB  
classifier = GaussianNB()  
classifier.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
# Predicting the Test set results  
y_pred = classifier.predict(x_test)

# %%
len(y_pred)
# Out:
# 300

# %%
# Making the Confusion Matrix  
from sklearn.metrics import confusion_matrix
cm_nb = confusion_matrix(y_test,y_pred)
plt.figure(figsize=(8,2))
plt.title("Naive Bayes Confusion Matrix")
sns.heatmap(cm_nb,annot=True,cmap="Blues",fmt="d",cbar=False, annot_kws={"size": 16})
# Out:
# <AxesSubplot:title={'center':'Naive Bayes Confusion Matrix'}>

# %% [markdown]
# ### As we can see in the above confusion matrix output, there are 16+53= 69 incorrect predictions, and 161+60=221 correct predictions.

# %%
from sklearn.metrics import f1_score
print(f1_score(y_test, y_pred))
# Out:
# 0.8029925187032418

# %%
# Out:
# 1

# %%
# Out:
# 2

# %% [markdown]
# ## Convert continuous features to Categorical features

# %%
df["cat_Duration in month"] = pd.cut(data["Duration in month"].values, bins = 3, labels = [0,1,2])
df["cat_Credit amount"] = pd.cut(data["Credit amount"].values, bins = 3, labels = [0,1,2])
df["cat_Installment rate in percentage of disposable income"] = pd.cut(data["Installment rate in percentage of disposable income"].values, bins = 3, labels = [0,1,2])
df["cat_Present residence since"] = pd.cut(data["Present residence since"].values, bins = 3, labels = [0,1,2])
df["cat_Age in years"] = pd.cut(data["Age in years"].values, bins = 3, labels = [0,1,2])
df["cat_Number of existing credits at this bank"] = pd.cut(data["Number of existing credits at this bank"].values, bins = 3, labels = [0,1,2])
df["cat_Number of people being liable to provide maintenance for"] = pd.cut(data["Number of people being liable to provide maintenance for"].values, bins = 3, labels = [0,1,2])
df = df.drop(columns=["Duration in month","Credit amount","Present residence since","Age in years","Number of existing credits at this bank","Number of people being liable to provide maintenance for"])
df.head()
# Out:
#    Installment rate in percentage of disposable income  actual classification  \
# 0                                                  4                        1
# 1                                                  2                        2
# 2                                                  2                        1
# 3                                                  2                        1
# 4                                                  3                        2
#
#    Status of existing checking account_cat  Credit history_cat  Purpose_cat  \
# 0                                        0                   4            4
# 1                                        1                   2            4
# 2                                        3                   4            7
# 3                                        0                   2            3
# 4                                        0                   3            0
#
# ...

# %%
df.head()
# Out:
#    Installment rate in percentage of disposable income  actual classification  \
# 0                                                  4                        1
# 1                                                  2                        2
# 2                                                  2                        1
# 3                                                  2                        1
# 4                                                  3                        2
#
#    Status of existing checking account_cat  Credit history_cat  Purpose_cat  \
# 0                                        0                   4            4
# 1                                        1                   2            4
# 2                                        3                   4            7
# 3                                        0                   2            3
# 4                                        0                   3            0
#
# ...

# %%
counts = obj_df["Status of existing checking account"].value_counts()
percent100 = obj_df["Status of existing checking account"].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
light_conditions=pd.DataFrame({'counts': counts, 'Percent': percent100})
print(light_conditions)
counts = obj_df["Personal status and sex"].value_counts()
percent100 = obj_df["Personal status and sex"].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
light_conditions=pd.DataFrame({'counts': counts, 'Percent': percent100})
print(light_conditions)
counts = obj_df["Property"].value_counts()
percent100 = obj_df["Property"].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
acc_day=pd.DataFrame({'counts': counts, 'Percent': percent100})
print(acc_day)
counts = obj_df["Job"].value_counts()
percent100 = obj_df["Job"].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
acc_day=pd.DataFrame({'counts': counts, 'Percent': percent100})
print(acc_day)
# Out:
#      counts Percent
# A14     394   39.4%
# A11     274   27.4%
# A12     269   26.9%
# A13      63    6.3%
#      counts Percent
# A93     548   54.8%
# A92     310   31.0%
# A94      92    9.2%
# A91      50    5.0%
#       counts Percent
# A123     332   33.2%
# A121     282   28.2%
# A122     232   23.2%
# A124     154   15.4%
#       counts Percent
# A173     630   63.0%
# A172     200   20.0%
# A174     148   14.8%
# A171      22    2.2%

# %%
counts = obj_df["Credit history"].value_counts()
percent100 = obj_df["Credit history"].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
light_conditions=pd.DataFrame({'counts': counts, 'Percent': percent100})
print(light_conditions)
counts = obj_df["Savings account/bonds"].value_counts()
percent100 = obj_df["Savings account/bonds"].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
light_conditions=pd.DataFrame({'counts': counts, 'Percent': percent100})
print(light_conditions)
counts = obj_df["Present employment since"].value_counts()
percent100 = obj_df["Present employment since"].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
acc_day=pd.DataFrame({'counts': counts, 'Percent': percent100})
print(acc_day)
# Out:
#      counts Percent
# A32     530   53.0%
# A34     293   29.3%
# A33      88    8.8%
# A31      49    4.9%
# A30      40    4.0%
#      counts Percent
# A61     603   60.3%
# A65     183   18.3%
# A62     103   10.3%
# A63      63    6.3%
# A64      48    4.8%
#      counts Percent
# A73     339   33.9%
# A75     253   25.3%
# A74     174   17.4%
# A72     172   17.2%
# A71      62    6.2%

# %%
counts = obj_df["Purpose"].value_counts()
percent100 = obj_df["Purpose"].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
acc_day=pd.DataFrame({'counts': counts, 'Percent': percent100})
print(acc_day)
# Out:
#       counts Percent
# A43      280   28.0%
# A40      234   23.4%
# A42      181   18.1%
# A41      103   10.3%
# A49       97    9.7%
# A46       50    5.0%
# A45       22    2.2%
# A410      12    1.2%
# A44       12    1.2%
# A48        9    0.9%

# %%
Status of existing checking account     4
Credit history                          5
Purpose                                10
Savings account/bonds                   5
Present employment since                5
Personal status and sex                 4
Other debtors / guarantors              3
Property                                4
Other installment plans                 3
Housing                                 3
Job                                     4
Telephone                               2
foreign worker
