# %%
import pandas as pd

# %%
# !dir "./data"
# Out:
#  Volume in drive D is Local Disk
#  Volume Serial Number is A250-145C
#
#  Directory of d:\Frong\Github\software development\SC348810-Software-Development-and-Project-Management-for-Data-Science-and-Artificial-Intelligence\data
#
# 07/28/2022  02:24 PM    <DIR>          .
# 07/28/2022  02:24 PM    <DIR>          ..
# 07/28/2022  01:36 PM           102,000 german_data-numeric.txt
# 07/28/2022  01:36 PM            79,793 german_data.txt
#                2 File(s)        181,793 bytes
#                2 Dir(s)  845,441,937,408 bytes free

# %%
# """Description
# Attribute 1: (qualitative)
# Status of existing checking account
# A11 : ... < 0 DM
# A12 : 0 <= ... < 200 DM
# A13 : ... >= 200 DM / salary assignments for at least 1 year
# A14 : no checking account
# _____________________________________________________________________________________________
# Attribute 2: (numerical)
# Duration in month
# _____________________________________________________________________________________________
# Attribute 3: (qualitative)
# Credit history
# A30 : no credits taken/ all credits paid back duly
# A31 : all credits at this bank paid back duly
# A32 : existing credits paid back duly till now
# A33 : delay in paying off in the past
# A34 : critical account/ other credits existing (not at this bank)
# _____________________________________________________________________________________________
# Attribute 4: (qualitative)
# Purpose
# A40 : car (new)
# A41 : car (used)
# A42 : furniture/equipment
# A43 : radio/television
# A44 : domestic appliances
# A45 : repairs
# A46 : education
# A47 : (vacation - does not exist?)
# A48 : retraining
# A49 : business
# A410 : others
# _____________________________________________________________________________________________
# Attribute 5: (numerical)
# Credit amount
# _____________________________________________________________________________________________
# Attibute 6: (qualitative)
# Savings account/bonds
# A61 : ... < 100 DM
# A62 : 100 <= ... < 500 DM
# A63 : 500 <= ... < 1000 DM
# A64 : .. >= 1000 DM
# A65 : unknown/ no savings account
# _____________________________________________________________________________________________
# Attribute 7: (qualitative)
# Present employment since
# A71 : unemployed
# A72 : ... < 1 year
# A73 : 1 <= ... < 4 years
# A74 : 4 <= ... < 7 years
# A75 : .. >= 7 years
# _____________________________________________________________________________________________
# Attribute 8: (numerical)
# Installment rate in percentage of disposable income
# _____________________________________________________________________________________________
# Attribute 9: (qualitative)
# Personal status and sex
# A91 : male : divorced/separated
# A92 : female : divorced/separated/married
# A93 : male : single
# A94 : male : married/widowed
# A95 : female : single
# _____________________________________________________________________________________________
# Attribute 10: (qualitative)
# Other debtors / guarantors
# A101 : none
# A102 : co-applicant
# A103 : guarantor
# _____________________________________________________________________________________________
# Attribute 11: (numerical)
# Present residence since
# _____________________________________________________________________________________________
# Attribute 12: (qualitative)
# Property
# A121 : real estate
# A122 : if not A121 : building society savings agreement/ life insurance
# A123 : if not A121/A122 : car or other, not in attribute 6
# A124 : unknown / no property
# _____________________________________________________________________________________________
# Attribute 13: (numerical)
# Age in years
# _____________________________________________________________________________________________
# Attribute 14: (qualitative)
# Other installment plans
# A141 : bank
# A142 : stores
# A143 : none
# _____________________________________________________________________________________________
# Attribute 15: (qualitative)
# Housing
# A151 : rent
# A152 : own
# A153 : for free
# _____________________________________________________________________________________________
# Attribute 16: (numerical)
# Number of existing credits at this bank
# _____________________________________________________________________________________________
# Attribute 17: (qualitative)
# Job
# A171 : unemployed/ unskilled - non-resident
# A172 : unskilled - resident
# A173 : skilled employee / official
# A174 : management/ self-employed/
# highly qualified employee/ officer
# _____________________________________________________________________________________________
# Attribute 18: (numerical)
# Number of people being liable to provide maintenance for
# _____________________________________________________________________________________________
# Attribute 19: (qualitative)
# Telephone
# A191 : none
# A192 : yes, registered under the customers name
# _____________________________________________________________________________________________
# Attribute 20: (qualitative)
# foreign worker
# A201 : yes
# A202 : no
# _____________________________________________________________________________________________
# """

# %%
#data link https://archive.ics.uci.edu/ml/datasets/Statlog+%28German+Credit+Data%29
header_column = ["Status of existing checking account",
                "Duration in month",
                "Credit history",
                "Purpose",
                "Credit amount",
                "Savings account/bonds",
                "Present employment since",
                "Installment rate in percentage of disposable income",
                "Personal status and sex",
                "Other debtors / guarantors",
                "Present residence since",
                "Property",
                "Age in years",
                "Other installment plans",
                "Housing",
                "Number of existing credits at this bank",
                "Job",
                "Number of people being liable to provide maintenance for",
                "Telephone",
                "foreign worker",
                "actual classification"]

data = pd.read_csv("./data/german_data.txt", sep = " ", names = header_column)
df = pd.DataFrame(data = data, index = [i for i in range(0,1000)])
df
# print(data)
# Out:
#     Status of existing checking account  Duration in month Credit history  \
# 0                                   A11                  6            A34
# 1                                   A12                 48            A32
# 2                                   A14                 12            A34
# 3                                   A11                 42            A32
# 4                                   A11                 24            A33
# ..                                  ...                ...            ...
# 995                                 A14                 12            A32
# 996                                 A11                 30            A32
# 997                                 A14                 12            A32
# 998                                 A11                 45            A32
# 999                                 A12                 45            A34
#
#     Purpose  Credit amount Savings account/bonds Present employment since  \
# 0       A43           1169                   A65                      A75
# 1       A43           5951                   A61                      A73
# 2       A46           2096                   A61                      A74
# 3       A42           7882                   A61                      A74
# 4       A40           4870                   A61                      A73
# ..      ...            ...                   ...                      ...
# 995     A42           1736                   A61                      A74
# 996     A41           3857                   A61                      A73
# 997     A43            804                   A61                      A75
# 998     A43           1845                   A61                      A73
# 999     A41           4576                   A62                      A71
#
#      Installment rate in percentage of disposable income  \
# 0                                                    4
# 1                                                    2
# 2                                                    2
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 995                                                  3
# 996                                                  4
# 997                                                  4
# 998                                                  4
# 999                                                  3
#
#     Personal status and sex Other debtors / guarantors  ...  Property  \
# 0                       A93                       A101  ...      A121
# 1                       A92                       A101  ...      A121
# 2                       A93                       A101  ...      A121
# 3                       A93                       A103  ...      A122
# 4                       A93                       A101  ...      A124
# ..                      ...                        ...  ...       ...
# 995                     A92                       A101  ...      A121
# 996                     A91                       A101  ...      A122
# 997                     A93                       A101  ...      A123
# 998                     A93                       A101  ...      A124
# 999                     A93                       A101  ...      A123
#
#     Age in years  Other installment plans Housing  \
# 0             67                     A143    A152
# 1             22                     A143    A152
# 2             49                     A143    A152
# 3             45                     A143    A153
# 4             53                     A143    A153
# ..           ...                      ...     ...
# 995           31                     A143    A152
# 996           40                     A143    A152
# 997           38                     A143    A152
# 998           23                     A143    A153
# 999           27                     A143    A152
#
#     Number of existing credits at this bank   Job  \
# 0                                         2  A173
# 1                                         1  A173
# 2                                         1  A172
# 3                                         1  A173
# 4                                         2  A173
# ..                                      ...   ...
# 995                                       1  A172
# 996                                       1  A174
# 997                                       1  A173
# 998                                       1  A173
# 999                                       1  A173
#
#     Number of people being liable to provide maintenance for  Telephone  \
# 0                                                    1             A192
# 1                                                    1             A191
# 2                                                    2             A191
# 3                                                    2             A191
# 4                                                    2             A191
# ..                                                 ...              ...
# 995                                                  1             A191
# 996                                                  1             A192
# 997                                                  1             A191
# 998                                                  1             A192
# 999                                                  1             A191
#
#     foreign worker actual classification
# 0             A201                     1
# 1             A201                     2
# 2             A201                     1
# 3             A201                     1
# 4             A201                     2
# ..             ...                   ...
# 995           A201                     1
# 996           A201                     1
# 997           A201                     1
# 998           A201                     2
# 999           A201                     1
#
# [1000 rows x 21 columns]

# %%
for index, data in enumerate(df["Status of existing checking account"]):
    if data == "A11":
        df["Status of existing checking account"][index] = 1
    elif data == "A12":
        df["Status of existing checking account"][index] = 2
    elif data == "A13":
        df["Status of existing checking account"][index] = 3
    elif data == "A14":
        df["Status of existing checking account"][index] = 4
    else:
        continue
# Out:
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\3301947182.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Status of existing checking account"][index] = 1
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\3301947182.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Status of existing checking account"][index] = 2
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\3301947182.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Status of existing checking account"][index] = 4
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\3301947182.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Status of existing checking account"][index] = 3

# %%
for index, data in enumerate(df["Credit history"]):
    if data == "A30":
        df["Credit history"][index] = 1
    elif data == "A31":
        df["Credit history"][index] = 2
    elif data == "A32":
       df["Credit history"][index] = 3
    elif data == "A33":
        df["Credit history"][index] = 4
    elif data == "A34":
        df["Credit history"][index] = 5
    else:
        continue
# Out:
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\3107446328.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Credit history"][index] = 5
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\3107446328.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Credit history"][index] = 3
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\3107446328.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Credit history"][index] = 4
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\3107446328.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Credit history"][index] = 1
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\3107446328.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Credit history"][index] = 2

# %%
for index, data in enumerate(df["Purpose"]):
    if data == "A40":
        df["Purpose"][index] = 1
    elif data == "A41":
        df["Purpose"][index] = 2
    elif data == "A42":
       df["Purpose"][index] = 3
    elif data == "A43":
        df["Purpose"][index] = 4
    elif data == "A44":
        df["Purpose"][index] = 5
    elif data == "A45":
        df["Purpose"][index] = 6
    elif data == "A46":
        df["Purpose"][index] = 7
    elif data == "A47":
        df["Purpose"][index] = 8
    elif data == "A48":
        df["Purpose"][index] = 9
    elif data == "A49":
        df["Purpose"][index] = 10
    elif data == "A410":
        df["Purpose"][index] = 11
    else:
        continue
# Out:
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\633307128.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Purpose"][index] = 4
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\633307128.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Purpose"][index] = 7
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\633307128.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Purpose"][index] = 3
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\633307128.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Purpose"][index] = 1
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\633307128.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Purpose"][index] = 2
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\633307128.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Purpose"][index] = 10
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\633307128.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Purpose"][index] = 5
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\633307128.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Purpose"][index] = 6
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\633307128.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Purpose"][index] = 11
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\633307128.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Purpose"][index] = 9

# %%
for index, data in enumerate(df["Savings account/bonds"]):
    if data == "A61":
        df["Savings account/bonds"][index] = 1
    elif data == "A62":
        df["Savings account/bonds"][index] = 2
    elif data == "A63":
       df["Savings account/bonds"][index] = 3
    elif data == "A64":
        df["Savings account/bonds"][index] = 4
    elif data == "A65":
        df["Savings account/bonds"][index] = 5
    else:
        continue
# Out:
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\2378798832.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Savings account/bonds"][index] = 5
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\2378798832.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Savings account/bonds"][index] = 1
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\2378798832.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Savings account/bonds"][index] = 3
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\2378798832.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Savings account/bonds"][index] = 4
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\2378798832.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Savings account/bonds"][index] = 2

# %%
for index, data in enumerate(df["Present employment since"]):
    if data == "A71":
        df["Present employment since"][index] = 1
    elif data == "A72":
        df["Present employment since"][index] = 2
    elif data == "A73":
       df["Present employment since"][index] = 3
    elif data == "A74":
        df["Present employment since"][index] = 4
    elif data == "A75":
        df["Present employment since"][index] = 5
    else:
        continue
# Out:
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\460084329.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Present employment since"][index] = 5
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\460084329.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Present employment since"][index] = 3
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\460084329.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Present employment since"][index] = 4
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\460084329.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Present employment since"][index] = 1
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\460084329.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Present employment since"][index] = 2

# %%
for index, data in enumerate(df["Personal status and sex"]):
    if data == "A91":
        df["Personal status and sex"][index] = 1
    elif data == "A92":
        df["Personal status and sex"][index] = 2
    elif data == "A93":
       df["Personal status and sex"][index] = 3
    elif data == "A94":
        df["Personal status and sex"][index] = 4
    elif data == "A95":
        df["Personal status and sex"][index] = 5
    else:
        continue
# Out:
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\2109257078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Personal status and sex"][index] = 3
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\2109257078.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Personal status and sex"][index] = 2
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\2109257078.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Personal status and sex"][index] = 1
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\2109257078.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Personal status and sex"][index] = 4

# %%
for index, data in enumerate(df["Other debtors / guarantors"]):
    if data == "A101":
        df["Other debtors / guarantors"][index] = 1
    elif data == "A102":
        df["Other debtors / guarantors"][index] = 2
    elif data == "A103":
       df["Other debtors / guarantors"][index] = 3
    else:
        continue
# Out:
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\914738569.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Other debtors / guarantors"][index] = 1
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\914738569.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Other debtors / guarantors"][index] = 3
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\914738569.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Other debtors / guarantors"][index] = 2

# %%
for index, data in enumerate(df["Property"]):
    if data == "A121":
        df["Property"][index] = 1
    elif data == "A122":
        df["Property"][index] = 2
    elif data == "A123":
       df["Property"][index] = 3
    elif data == "A124":
       df["Property"][index] = 4
    else:
        continue
# Out:
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\216476550.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Property"][index] = 1
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\216476550.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Property"][index] = 2
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\216476550.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Property"][index] = 4
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\216476550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Property"][index] = 3

# %%
for index, data in enumerate(df["Other installment plans"]):
    if data == "A141":
        df["Other installment plans"][index] = 1
    elif data == "A142":
        df["Other installment plans"][index] = 2
    elif data == "A143":
       df["Other installment plans"][index] = 3
    else:
        continue
# Out:
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\3923032981.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Other installment plans"][index] = 3
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\3923032981.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Other installment plans"][index] = 1
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\3923032981.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Other installment plans"][index] = 2

# %%
for index, data in enumerate(df["Housing"]):
    if data == "A151":
        df["Housing"][index] = 1
    elif data == "A152":
        df["Housing"][index] = 2
    elif data == "A153":
       df["Housing"][index] = 3
    else:
        continue
# Out:
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\3405802806.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Housing"][index] = 2
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\3405802806.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Housing"][index] = 3
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\3405802806.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Housing"][index] = 1

# %%
for index, data in enumerate(df["Job"]):
    if data == "A171":
        df["Job"][index] = 1
    elif data == "A172":
        df["Job"][index] = 2
    elif data == "A173":
       df["Job"][index] = 3
    elif data == "A174":
       df["Job"][index] = 4
    else:
        continue
# Out:
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\1143171095.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Job"][index] = 3
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\1143171095.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Job"][index] = 2
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\1143171095.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Job"][index] = 4
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\1143171095.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Job"][index] = 1

# %%
for index, data in enumerate(df["Telephone"]):
    if data == "A191":
        df["Telephone"][index] = 1
    elif data == "A192":
        df["Telephone"][index] = 2
    else:
        continue
# Out:
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\768855376.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Telephone"][index] = 2
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\768855376.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Telephone"][index] = 1

# %%
for index, data in enumerate(df["foreign worker"]):
    if data == "A201":
        df["foreign worker"][index] = 1
    elif data == "A202":
        df["foreign worker"][index] = 2
    else:
        continue
# Out:
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\1903884923.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["foreign worker"][index] = 1
# C:\Users\FRONG\AppData\Local\Temp\ipykernel_8656\1903884923.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["foreign worker"][index] = 2

# %%
df
# Out:
#     Status of existing checking account  Duration in month Credit history  \
# 0                                     1                  6              5
# 1                                     2                 48              3
# 2                                     4                 12              5
# 3                                     1                 42              3
# 4                                     1                 24              4
# ..                                  ...                ...            ...
# 995                                   4                 12              3
# 996                                   1                 30              3
# 997                                   4                 12              3
# 998                                   1                 45              3
# 999                                   2                 45              5
#
#     Purpose  Credit amount Savings account/bonds Present employment since  \
# 0         4           1169                     5                        5
# 1         4           5951                     1                        3
# 2         7           2096                     1                        4
# 3         3           7882                     1                        4
# 4         1           4870                     1                        3
# ..      ...            ...                   ...                      ...
# 995       3           1736                     1                        4
# 996       2           3857                     1                        3
# 997       4            804                     1                        5
# 998       4           1845                     1                        3
# 999       2           4576                     2                        1
#
#      Installment rate in percentage of disposable income  \
# 0                                                    4
# 1                                                    2
# 2                                                    2
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 995                                                  3
# 996                                                  4
# 997                                                  4
# 998                                                  4
# 999                                                  3
#
#     Personal status and sex Other debtors / guarantors  ...  Property  \
# 0                         3                          1  ...         1
# 1                         2                          1  ...         1
# 2                         3                          1  ...         1
# 3                         3                          3  ...         2
# 4                         3                          1  ...         4
# ..                      ...                        ...  ...       ...
# 995                       2                          1  ...         1
# 996                       1                          1  ...         2
# 997                       3                          1  ...         3
# 998                       3                          1  ...         4
# 999                       3                          1  ...         3
#
#     Age in years  Other installment plans Housing  \
# 0             67                        3       2
# 1             22                        3       2
# 2             49                        3       2
# 3             45                        3       3
# 4             53                        3       3
# ..           ...                      ...     ...
# 995           31                        3       2
# 996           40                        3       2
# 997           38                        3       2
# 998           23                        3       3
# 999           27                        3       2
#
#     Number of existing credits at this bank  Job  \
# 0                                         2    3
# 1                                         1    3
# 2                                         1    2
# 3                                         1    3
# 4                                         2    3
# ..                                      ...  ...
# 995                                       1    2
# 996                                       1    4
# 997                                       1    3
# 998                                       1    3
# 999                                       1    3
#
#     Number of people being liable to provide maintenance for  Telephone  \
# 0                                                    1                2
# 1                                                    1                1
# 2                                                    2                1
# 3                                                    2                1
# 4                                                    2                1
# ..                                                 ...              ...
# 995                                                  1                1
# 996                                                  1                2
# 997                                                  1                1
# 998                                                  1                2
# 999                                                  1                1
#
#     foreign worker actual classification
# 0                1                     1
# 1                1                     2
# 2                1                     1
# 3                1                     1
# 4                1                     2
# ..             ...                   ...
# 995              1                     1
# 996              1                     1
# 997              1                     1
# 998              1                     2
# 999              1                     1
#
# [1000 rows x 21 columns]
